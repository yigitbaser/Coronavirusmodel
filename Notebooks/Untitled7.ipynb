# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir) 
from src.Data.gathering import gathering
import pandas as pd
from src.Utils.Loader import Loader

# %%
df = gathering.get_total_deaths_data()

# %%
df
# Out:
#        Date  Total Deaths  Change in Total Change in Total (%)
# 0   Mar. 21         13013             1626                 14%
# 1   Mar. 20         11387             1356                 14%
# 2   Mar. 19         10031             1080                 12%
# 3   Mar. 18          8951              973                 12%
# 4   Mar. 17          7978              817                 11%
# 5   Mar. 16          7161              642                 10%
# 6   Mar. 15          6519              686                 12%
# 7   Mar. 14          5833              404                  7%
# 8   Mar. 13          5429              448                  9%
# 9   Mar. 12          4981              353                  8%
# 10  Mar. 11          4628              332                  8%
# 11  Mar. 10          4296              271                  7%
# 12   Mar. 9          4025              198                  5%
# 13   Mar. 8          3827              228                  6%
# ...

# %%
timeof= df[df['Date']=='Jan. 23']

# %%
pd.Timestamp(2017, 1, 1, 12)
# Out:
# Timestamp('2017-01-01 12:00:00')

# %%
total_data = Loader.load_data("/Users/yigitbaser/Coronavirusmodel/Storage/2020-03-22/TotalTable_77.csv")
total_data
# Out:
#      Unnamed: 0 Country,Other  TotalCases NewCases  TotalDeaths  NewDeaths  \
# 0             0         China       81054      +46       3261.0        6.0
# 1             1         Italy       53578      NaN       4825.0        NaN
# 2             2           USA       26888   +2,681        348.0       46.0
# 3             3         Spain       25496      NaN       1381.0        NaN
# 4             4       Germany       22364      NaN         84.0        NaN
# ..          ...           ...         ...      ...          ...        ...
# 185         185  Sint Maarten           1      NaN          NaN        NaN
# 186         186       Somalia           1      NaN          NaN        NaN
# 187         187   Timor-Leste           1      NaN          NaN        NaN
# 188         188        Uganda           1      NaN          NaN        NaN
# 189         189        Total:      308473     3483      13069.0       62.0
#
# ...

# %%
type(total_data['TimeStamp'][5])
# Out:
# str

# %%
pd.Timestamp(total_data['TimeStamp'][5])
# Out:
# Timestamp('2020-03-22 07:07:57.554497')

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        190 non-null    int64
#  1   Country,Other     190 non-null    object
#  2   TotalCases        190 non-null    int64
#  3   NewCases          17 non-null     object
#  4   TotalDeaths       88 non-null     float64
#  5   NewDeaths         7 non-null      float64
#  6   TotalRecovered    106 non-null    float64
#  7   ActiveCases       190 non-null    int64
#  8   Serious,Critical  73 non-null     float64
#  9   Tot Cases/1M pop  189 non-null    float64
#  10  TimeStamp         190 non-null    object
# dtypes: float64(5), int64(3), object(3)
# memory usage: 16.5+ KB

# %%
# Out:
# dtype('O')
