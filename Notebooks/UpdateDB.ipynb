# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from src.Data.gathering import gathering as gt
from src.Utils.SaverUtils import Saver

# %%
gt.get_total_deaths_data()
# Out:
#        Date  Total Deaths  Change in Total Change in Total (%)
# 0    Apr. 1         47192             4883                 12%
# 1   Mar. 31         42309             4535                 12%
# 2   Mar. 30         37774             3709                 11%
# 3   Mar. 29         34065             3204                 10%
# 4   Mar. 28         30861             3518                 13%
# ..      ...           ...              ...                 ...
# 65  Jan. 27           106               26                 33%
# 66  Jan. 26            80               24                 43%
# 67  Jan. 25            56               15                 37%
# 68  Jan. 24            41               16                 64%
# 69  Jan. 23            25                8                 47%
#
# [70 rows x 4 columns]

# %%
s = Saver.DATA_TO_IMPORT
s
# Out:
# {'DataAge',
#  'DataDailyDeath',
#  'DataPrecondition',
#  'DataSex',
#  'DataTotalDeath',
#  'TotalTable'}

# %%
df = gt.run('TotalTable')

# %%
df
# Out:
#         Country,Other  TotalCases NewCases  TotalDeaths NewDeaths  \
# 0                 USA      216265   +1,262       5132.0       +30
# 1               Italy      110574      NaN      13155.0       NaN
# 2               Spain      110238   +6,120      10003.0      +616
# 3             Germany       80641   +2,660        962.0       +31
# 4              France       56989      NaN       4032.0       NaN
# ..                ...         ...      ...          ...       ...
# 201      Sierra Leone           2      NaN          NaN       NaN
# 202  Papua New Guinea           1      NaN          NaN       NaN
# 203       Timor-Leste           1      NaN          NaN       NaN
# 204             China       81589      +35       3318.0        +6
# 205            Total:      962882  +27,685      49191.0    +1,999
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0            8904.0       202229            5005.0             653.0
# ...

# %%
for type_data in Saver.DATA_TO_IMPORT:
    real_data = gt.run(type_data)
    file_loc = "/Users/yigitbaser/Coronavirusmodel/Storage/RealData/02042020/"+type_data+".csv"
    Saver.save_to_directory(data_to_save=real_data,directory= file_loc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c72885ae2957> in <module>
#       2     real_data = gt.run(type_data)
#       3     file_loc = "/Users/yigitbaser/Coronavirusmodel/Storage/RealData/02042020/"+type_data+".csv"
# ----> 4     Saver.save_to_directory(data_to_save=real_data,directory= file_loc)
#
# ~/Coronavirusmodel/src/Utils/SaverUtils.py in save_to_directory(data_to_save, directory)
#      38
#      39     def save_to_directory(data_to_save: pd.DataFrame, directory: str):
# ---> 40             return data_to_save.to_csv(directory)
#      41
#      42     # def
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
df = gt.get_age_data()

# %%
df.to_csv("/Users/yigitbaser/Coronavirusmodel/Storage/RealData/02042020/AgeData.csv")

# %%
for type_data in Saver.DATA_TO_IMPORT:
    print(type_data)
# Out:
# DataTotalDeath
# DataDailyDeath
# DataSex
# TotalTable
# DataAge
# DataPrecondition

# %%
gt.get_precondition_data()
# Out:
#                              0                           1  \
# 0       PRE-EXISTING CONDITION  DEATH RATE confirmed cases
# 1       Cardiovascular disease                       13.2%
# 2                     Diabetes                        9.2%
# 3  Chronic respiratory disease                        8.0%
# 4                 Hypertension                        8.4%
# 5                       Cancer                        7.6%
# 6   no pre-existing conditions                         NaN
#
#                       2
# 0  DEATH RATE all cases
# 1                 10.5%
# 2                  7.3%
# 3                  6.3%
# 4                  6.0%
# 5                  5.6%
# 6                  0.9%

# %%
gt.run('DataPrecon')
# Out:
#                              0                           1  \
# 0       PRE-EXISTING CONDITION  DEATH RATE confirmed cases
# 1       Cardiovascular disease                       13.2%
# 2                     Diabetes                        9.2%
# 3  Chronic respiratory disease                        8.0%
# 4                 Hypertension                        8.4%
# 5                       Cancer                        7.6%
# 6   no pre-existing conditions                         NaN
#
#                       2
# 0  DEATH RATE all cases
# 1                 10.5%
# 2                  7.3%
# 3                  6.3%
# 4                  6.0%
# 5                  5.6%
# 6                  0.9%

# %%
Saver.save_to_directory(data_to_save = gt.run('DataPrecon'), directory = "/Users/yigitbaser/Coronavirusmodel/Storage/RealData/02042020/DataPrecon.csv")
