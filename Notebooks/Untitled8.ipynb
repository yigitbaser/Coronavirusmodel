# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir) 

from src.Data import visualization
import matplotlib.pyplot as plt
from src.Utils.Loader import Loader

# %%
death_data = Loader.load_data("/Users/yigitbaser/Coronavirusmodel/Storage/2020-03-22/DATATOTALDEATH_77.csv")

# %%
visualization.visual.plot_total_death("/Users/yigitbaser/Coronavirusmodel/Storage/2020-03-22/DATATOTALDEATH_77.csv_77.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-e1ac43925f94> in <module>
# ----> 1 visualization.visual.plot_total_death("/Users/yigitbaser/Coronavirusmodel/Storage/2020-03-22/DATATOTALDEATH_77.csv_77.csv")
#
# ~/Coronavirusmodel/src/Data/visualization.py in plot_total_death(self)
#      18         """
#      19
# ---> 20         :return:
#      21         """
#      22         death_data = Loader.load_data("/Users/yigitbaser/Coronavirusmodel/Storage/2020-03-22/DATATOTALDEATH_77.csv")
#
# AttributeError: 'str' object has no attribute 'TABLE_PATH'

# %%
death_data
# Out:
#     Unnamed: 0     Date  Total Deaths  Change in Total Change in Total (%)  \
# 0            0  Mar. 21         13013             1626                 14%
# 1            1  Mar. 20         11387             1356                 14%
# 2            2  Mar. 19         10031             1080                 12%
# 3            3  Mar. 18          8951              973                 12%
# 4            4  Mar. 17          7978              817                 11%
# 5            5  Mar. 16          7161              642                 10%
# 6            6  Mar. 15          6519              686                 12%
# 7            7  Mar. 14          5833              404                  7%
# 8            8  Mar. 13          5429              448                  9%
# 9            9  Mar. 12          4981              353                  8%
# 10          10  Mar. 11          4628              332                  8%
# ...

# %%
death_data[:5]
# Out:
#    Unnamed: 0     Date  Total Deaths  Change in Total Change in Total (%)  \
# 0           0  Mar. 21         13013             1626                 14%
# 1           1  Mar. 20         11387             1356                 14%
# 2           2  Mar. 19         10031             1080                 12%
# 3           3  Mar. 18          8951              973                 12%
# 4           4  Mar. 17          7978              817                 11%
#
#                     TimeStamp
# 0  2020-03-22 07:07:57.554497
# 1  2020-03-22 07:07:57.554497
# 2  2020-03-22 07:07:57.554497
# 3  2020-03-22 07:07:57.554497
# 4  2020-03-22 07:07:57.554497

# %%
plt.figure()

# %%
death_data.plot(x='Date',y='Total Deaths')

# %%
a = visualization.visual()
type(a.table_path)
#a.plot_total_death()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-b774ef7a00da> in <module>
#       1 a = visualization.visual()
# ----> 2 type(a.table_path)
#       3 #a.plot_total_death()
#
# AttributeError: 'visual' object has no attribute 'table_path'

# %%
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-e00115e8401d> in <module>
# ----> 1 a.plot_total_death()
#
# ~/Coronavirusmodel/src/Data/visualization.py in plot_total_death(self)
#      18         """
#      19
# ---> 20         :return:
#      21         """
#      22         death_data = Loader.load_data("/Users/yigitbaser/Coronavirusmodel/Storage/2020-03-22/DATATOTALDEATH_77.csv")
#
# AttributeError: 'visual' object has no attribute 'TABLE_PATH'

# %%
death_data.plot(x='Date', y='Total Deaths')

# %%
visualization.visual.plot_total_death()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-1a9f678f7e2c> in <module>
# ----> 1 visualization.visual.plot_total_death()
#
# TypeError: plot_total_death() missing 1 required positional argument: 'self'
