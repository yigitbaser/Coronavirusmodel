# %%
from src.Processing.Processing import Process
from src.Data.gathering import gathering
from src.Utils.Loader import Loader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-898cde69f0f5> in <module>
# ----> 1 from src.Processing.Processing import Process
#       2 from src.Data.gathering import gathering
#       3 from src.Utils.Loader import Loader
#
# ModuleNotFoundError: No module named 'src'

# %%
TABLE_PATH = "/Users/yigitbaser/Coronavirusmodel/Storage/2020-03-22/TotalTable_77.csv"

# %%
total_table = Loader.load_data(TABLE_PATH)
total_table[:5]
# Out:
#    Unnamed: 0 Country,Other  TotalCases NewCases  TotalDeaths  NewDeaths  \
# 0           0         China       81054      +46       3261.0        6.0
# 1           1         Italy       53578      NaN       4825.0        NaN
# 2           2           USA       26888   +2,681        348.0       46.0
# 3           3         Spain       25496      NaN       1381.0        NaN
# 4           4       Germany       22364      NaN         84.0        NaN
#
#    TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0         72440.0         5353            1845.0              56.0
# 1          6072.0        42681            2857.0             886.0
# 2           178.0        26362             708.0              81.0
# 3          2125.0        21990            1612.0             545.0
# 4           209.0        22071               2.0             267.0
#
#                     TimeStamp
# 0  2020-03-22 07:07:57.554497
# 1  2020-03-22 07:07:57.554497
# ...

# %%
int(total_table[total_table['Country,Other'] == "France"]['TotalCases'])
# Out:
# 14459

# %%
Process.get_country_case_number(country='France',data_type='TotalCases',total_case_table=  TABLE_PATH)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-1193a33c48a2> in <module>
# ----> 1 Process.get_country_case_number(country='France',data_type='TotalCases',total_case_table=  TABLE_PATH)
#
# ~/Coronavirusmodel/src/Processing/Processing.py in get_country_case_number(country, data_type, total_case_table)
#       5     def __init__(self):
#       6         version = 'firstVersion'
# ----> 7
#       8     def get_country_case_number(country:str, data_type:str, total_case_table_path:str) -> int:
#       9         total_case_table = Loader.load_data(total_case_table_path)
#
# TypeError: string indices must be integers

# %%
int(total_table[total_table['Country,Other'] == 'France']['TotalCases'])
# Out:
# 14459

# %%
type(total_table['TotalCases'].sum())
# Out:
# numpy.int64

# %%
total_table
# Out:
#      Unnamed: 0 Country,Other  TotalCases NewCases  TotalDeaths  NewDeaths  \
# 0             0         China       81054      +46       3261.0        6.0
# 1             1         Italy       53578      NaN       4825.0        NaN
# 2             2           USA       26888   +2,681        348.0       46.0
# 3             3         Spain       25496      NaN       1381.0        NaN
# 4             4       Germany       22364      NaN         84.0        NaN
# ..          ...           ...         ...      ...          ...        ...
# 185         185  Sint Maarten           1      NaN          NaN        NaN
# 186         186       Somalia           1      NaN          NaN        NaN
# 187         187   Timor-Leste           1      NaN          NaN        NaN
# 188         188        Uganda           1      NaN          NaN        NaN
# 189         189        Total:      308473     3483      13069.0       62.0
#
# ...
